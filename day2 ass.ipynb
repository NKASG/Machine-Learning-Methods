# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
pwd
# Out:
# '/content'

# %%
data_path = "/content/sample_data/using.csv "

# %%
print(data_path)

# %%
data = pd.read_csv(filepath_or_buffer=data_path, header=None, delimiter=",")
